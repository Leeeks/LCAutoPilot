# %%
# OpenLCA data extraction script for the bill of materials structure of Xylem

# %%
import olca_ipc as ipc
import olca_schema as schema
import pandas as pd
import json

# %%
# Pfad zur Excel-Datei
excel_file_path = 'C:\\Users\\ale46522\\OneDrive - Fraunhofer\\Desktop\\Arbeit\\Xylem\\Python Skript - Automatisierung\\Bill_of_Materials.xlsx'

# Excel-Datei in ein DataFrame einlesen
df = pd.read_excel(excel_file_path)

# Sicherstellen, dass die Tabelle mindestens vier und neun Spalten hat
if df.shape[1] >= 9:
    # Daten in einem Dictionary speichern
    data_dict = {}
    for index, row in df.iterrows():
        process_name = row[3]  # String in der vierten Spalte
        process_category = row[8]  # Integer in der neunten Spalte
        data_dict[process_name] = process_category
else:
    data_dict = {}
    print("Die Tabelle hat weniger als neun Spalten.")

# Dictionary in einen formatierten JSON-String umwandeln
formatted_json = json.dumps(data_dict, indent=4)

# Den formatierten JSON-String ausgeben
# print(formatted_json)
# Out:
# C:\Users\ale46522\AppData\Local\Temp\ipykernel_24636\2340123147.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   process_name = row[3]  # String in der vierten Spalte
# C:\Users\ale46522\AppData\Local\Temp\ipykernel_24636\2340123147.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   process_category = row[8]  # Integer in der neunten Spalte

# %%
client = ipc.Client(8080)

client

# Zugriff auf einzelne Einträge im Dictionary
for process_name, process_category in data_dict.items():
    # Erstellung der Prozesse 
    process = schema.Process()
    process.name =  process_name
    process.description = f'This process represents the production of {process_name}.'
    process.process_type = schema.ProcessType.UNIT_PROCESS
    process.category = f'Ebene {process_category}'

    # Erstellung der Flows
    flow_property_factor = schema.FlowPropertyFactor()
    flow = schema.Flow()
    flow.name = process_name
    flow.category = 'Xylem_flow'
    flow.flow_properties = [flow_property_factor]
    flow.flow_type = schema.FlowType.PRODUCT_FLOW

    # Erstellung des Exchanges
    flow_property = schema.FlowProperty()
    unit = schema.Unit()
    exchange = schema.Exchange()
    exchange.is_input = False
    exchange.flow = flow
    exchange.flow_property = flow_property # Platzhalter
    exchange.unit = unit # Platzhalter
    exchange.amount = 1
    exchange.is_quantitative_reference = True

    # Einfügen der Exchanges in den Prozess
    process.exchanges = [exchange]
    
    
    
    # Prozess im OpenLCA-Client speichern
    client.put(flow)
    client.put(process)
    

    # print(f"{process_name} wurde erfolgreich erstellt.")
# Out:
# Flow(id='27263314-4f21-4172-a5b6-b8f2538dc70b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.557835Z', location=None, name='Baugr. SMOevoPLUS 910 Basis', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a5b1578e-f2d8-4f25-8d43-830bcb758524', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.587475Z', location=None, name='2/2-Wege Kugelhahn 3/4" ZF3110.24 1.4408/01', synonyms=None, tags=None, version='01.00.000')
# Flow(id='06eba4c2-c1ff-45f9-848b-dca75960ab67', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.596759Z', location=None, name='Flachdichtung DN15/PN40 DIN2690 PTFE', synonyms=None, tags=None, version='01.00.000')
# Flow(id='01f1137b-f570-46aa-8be6-23d7f4fc18a8', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.602765Z', location=None, name='Flachdichtung DN40/PN40 DIN2690 PTFE', synonyms=None, tags=None, version='01.00.000')
# Flow(id='58b03339-762f-4c27-85c1-ea912054c43e', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.612766Z', location=None, name='Widerstandsthermometer 2xPt100 (Set) 90D281', synonyms=None, tags=None, version='01.00.000')
# Flow(id='484936ba-cbd9-4910-a021-5236b7fb0d17', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.619767Z', location=None, name='Flansch Kremo  F40x48,3/PN10 DIN2642 1.430', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ccc89fe4-a3d0-4e80-9030-d279079cb4ad', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.627770Z', location=None, name='Baugr. Gas Ausgang 1 DN40 Schweißb', synonyms=None, tags=None, version='01.00.000')
# Flow(id='e1b0a511-e8f7-4a24-9ad1-659f303c2a9d', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.633771Z', location=None, name='Rohr  48,3x2,6 EN ISO1127 DIN17457 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='818dc500-958d-46a4-8a6c-a57458dd9761', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.639518Z', location=None, name='Rohrbogen DIN2605-1-90-3-48,3x2,6 W 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='dbd40736-eb47-4c48-aeba-6be80372b72e', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.648520Z', location=None, name='Bördel  G40x48,3 DIN2642 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='acf63405-5aed-4f7b-b3fb-762037ad3bf5', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.654470Z', location=None, name='Baugr. Gas Eingang DN40 Schweißba', synonyms=None, tags=None, version='01.00.000')
# Flow(id='2f0e3aea-9303-4dbe-9789-3946917522a0', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.663475Z', location=None, name='Nippel acc EN10241-1"x40-1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='15cb3d4f-a49b-4b7a-aeb6-d57c161e73b2', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.669474Z', location=None, name='Reduzierstück DIN2616-2-K-48,3x2,6-33,7x2,6', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1d1f0f25-d6ac-465e-8086-06a9cc7fcd26', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.677477Z', location=None, name='Muffe, egaler Abgang-EN10241-1/4"x25-1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='dc8f9563-b027-4e27-8043-0f3749d46dd9', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.683469Z', location=None, name='Gewindemuffe DN15/ 5/8"-18UNF 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='88fb83c2-751c-4430-8d97-417086a392b6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.690594Z', location=None, name='Baugr. Gas Ausgang 2 DN40 Schweißb', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6edcb225-ef80-4787-a1c2-ddb185f91d68', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.697594Z', location=None, name='Rückschlagventil mit Schweißenden DN40', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6021f580-2bfe-436f-b260-d86ffc58c993', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.704597Z', location=None, name='Anschweißkugelhahn mit Schweißenden DN40', synonyms=None, tags=None, version='01.00.000')
# Flow(id='f7a1c060-4249-4b5e-a424-8b27865d92a3', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.712646Z', location=None, name='Flansch Kremo  F100x114,3/PN10 DIN2642 1.4', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a23065eb-eda1-4aa9-a23a-b0d862738a21', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.718811Z', location=None, name='Baugr. Kühlwasser DN100 Schweißba', synonyms=None, tags=None, version='01.00.000')
# Flow(id='866699e2-edda-446b-97cc-7dc6eef930bc', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.726796Z', location=None, name='Rohr 114,3x2,6 EN ISO1127 DIN17457 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='027725ae-29f9-4d50-b96a-b50df7e15a9f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.732517Z', location=None, name='Nippel acc EN10241-1/2"x35-1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1f17eaaf-c95c-499a-a0d6-f948850d91ad', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.739533Z', location=None, name='Einschweißhülse GEMÜ DN25-300 KH 1.4435', synonyms=None, tags=None, version='01.00.000')
# Flow(id='41c5ba16-36fb-4e69-8c51-030f227475f1', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.746482Z', location=None, name='Bördel G100x114,3 DIN2642 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='c7ca177f-29e6-4586-bd19-3a120be5b454', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.751479Z', location=None, name='Gewindeflansch C40 DIN2566 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='095bad93-cdda-438b-8b3d-64fff0892a7e', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.756480Z', location=None, name='Stopfen -EN10241-1/4"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='f4dabcb5-a885-4f12-a98c-7a511412fb2a', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.762482Z', location=None, name='Doppelnippel, egal-EN10241-3/4"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='e60c204c-5756-4fbc-8301-1f618f685a5f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.767485Z', location=None, name='Doppelnippel, egal-EN10241-1 1/2"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ec5e9003-bbdb-4197-8267-e09b613fe507', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.774472Z', location=None, name='Doppelnippel, red.-EN10241-3/4"x1/2"-1.4571/V', synonyms=None, tags=None, version='01.00.000')
# Flow(id='22f674fd-fe2f-4613-968c-4d8c3ba1a2c2', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.781586Z', location=None, name='Doppelnippel reduced EN10241-1 1/2"x1"-1.457', synonyms=None, tags=None, version='01.00.000')
# Flow(id='8c6ef74c-5196-454a-9d09-4fb2bc544b34', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.787589Z', location=None, name='Reduzierstück-EN10241-3/4"x1/2"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='db9b3f55-d4bc-485d-8702-9ab2b1604eff', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.793589Z', location=None, name='Stopfen EN10241-1/2"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6536f0e6-6865-4dcf-838e-d8cfffd55f28', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.801739Z', location=None, name='Winkel, egaler Abgang-EN10241-3/4"-IG/IG-1.4', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6f25fc4e-b9c6-4a5f-a283-31a4cdc233c6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.808984Z', location=None, name='T-Stück, egaler Abgang-EN10241-1/2"-1.4571/V', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ca1f5952-5db0-4a54-a60c-0805b2d6033d', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.815974Z', location=None, name='Rohrdoppelnippel-EN10241-1/2"x100-1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='9d321286-5d86-46bd-a6a9-f45e3586fd84', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.823902Z', location=None, name='Halterungsschelle   kpl. 48,3mm DIN3015 PA S', synonyms=None, tags=None, version='01.00.000')
# Flow(id='538f4c09-859c-464e-8d20-48b87c6c6eb0', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.831219Z', location=None, name='Stopfen Wasserablauf selbstdichtend 3/8" Ms v', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6827d483-26f8-4b45-b38c-c1a9e1e2c57b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.838220Z', location=None, name='Manometerdichtring 1/4" VA', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ae722230-ec12-4671-a174-d79ed777a176', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.846226Z', location=None, name='Anflanschklappe Z014-A-LW DN100 -"A"- EBR', synonyms=None, tags=None, version='01.00.000')
# Flow(id='12fcb908-11d5-4ded-9e72-c1a4d71021ed', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.852134Z', location=None, name='Winkelverschraubung 6mm SS-6M0-9', synonyms=None, tags=None, version='01.00.000')
# Flow(id='05ffcf65-1515-455f-b873-9326de9c0241', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.858136Z', location=None, name='T-Verschraubung 6mm SS-6M0-3', synonyms=None, tags=None, version='01.00.000')
# Flow(id='bdc483e1-3417-415b-9627-4057ed0e00f0', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.865137Z', location=None, name='Manometerverschraubung 6mm - 1/4"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='0e1b7ac3-54a4-4077-937f-42955c5ab43f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.872138Z', location=None, name='Schlauch PB 3/4"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='b98a8e1d-9498-418e-b242-d8d10c04b152', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.878765Z', location=None, name='Winkeleinschraubverschraubung SS-6M0-2-4R', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4d06ee1e-0da5-4355-8659-5cab71dd0feb', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.883667Z', location=None, name='Blindstopfen 6mm SS-6M0-P', synonyms=None, tags=None, version='01.00.000')
# Flow(id='5a38e3bb-aad3-41a4-8b6b-412f82b37e51', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.889648Z', location=None, name='Präz.-Rohr, nahtlos 6x1,0 DIN2391 1.4571 OF+', synonyms=None, tags=None, version='01.00.000')
# Flow(id='0eb42e2f-1217-49b4-ab09-01463307639f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.897644Z', location=None, name='Manometer 0 bis +4 bar PGI-63B-BG4-LASX-A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ff41cf9d-6376-408b-a396-c62a81e2eb96', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.905651Z', location=None, name='Druckminderer G1" DM3305251/01/16-G 1.440', synonyms=None, tags=None, version='01.00.000')
# Flow(id='b4770623-b304-4507-ab6c-63d02553777b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.913651Z', location=None, name='Druckluftfilter DF-S0600-S G1 1/2" Donaldson', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4b34010e-ba8e-4099-b426-a32fc673c3eb', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.919913Z', location=None, name='Magnetisch-Induktiver Durchflussmesser mflow', synonyms=None, tags=None, version='01.00.000')
# Flow(id='8cc73a1f-6601-4af9-a157-dd3f4875d246', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.927914Z', location=None, name='Raumluftsensor O3 MST Satellite XT 0...1,00pp', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a3653989-0090-469d-a93f-32ec653cf2d7', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.934916Z', location=None, name='Transmitter MST Satellite XT 4-20mA / R f. O3/', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6021b073-a965-4d02-9690-7a6cfe1c364c', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.940918Z', location=None, name='Winkel Montagerahmen 100x70x75x5mm AlMg', synonyms=None, tags=None, version='01.00.000')
# Flow(id='44064d64-beea-4092-bc68-b48e544ea954', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.947919Z', location=None, name='Rohrdoppelnippel -EN10241-1 1/2"x200 -1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a0fa0e11-0dca-48c2-b836-4f677293a1c1', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.955921Z', location=None, name='Stopfen 5/8"-18 UNF 1.4571', synonyms=None, tags=None, version='01.00.000')
# Flow(id='67795618-d22e-402a-adee-1a53ccdd1735', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.962928Z', location=None, name='Dichtungsring DR 38 HDG3/8" verz.', synonyms=None, tags=None, version='01.00.000')
# Flow(id='bff78a9c-b427-419b-acc7-17e19f2761f7', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.970296Z', location=None, name='Montagerahmen Alu SMOevoPLUS 910 vormon', synonyms=None, tags=None, version='01.00.000')
# Flow(id='339095bc-8f9d-413d-9229-29760cb5022f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.981084Z', location=None, name='Montagerahmen EOZ SMOevoPLUS 910 S235', synonyms=None, tags=None, version='01.00.000')
# Flow(id='bfd5991a-5961-4f82-a5b7-9773f6a87d01', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.989086Z', location=None, name='2/2-Wege Magnetventil DN40', synonyms=None, tags=None, version='01.00.000')
# Flow(id='bc786b5f-53e8-4061-900c-cd3b9835f5b5', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:27.995086Z', location=None, name='Sicherheits Druckschalter Kombination DB1000', synonyms=None, tags=None, version='01.00.000')
# Flow(id='511fbb0d-5660-4f60-b1c5-356106c1e19b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.001088Z', location=None, name='Montageblech ZILA 160x160x3 AlMg3', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4adc94db-fa5a-4b1e-9f6e-4f0bf33521e2', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.006089Z', location=None, name='Einschraubverschraubung ,gerade 19,1mm-3/4"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='219da5d4-08f7-4d67-8711-956297567e4c', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.012090Z', location=None, name='Schlauchanschlussstück 19,1mm-19,1mm SS', synonyms=None, tags=None, version='01.00.000')
# Flow(id='b0e8aeac-ffa5-4064-bec2-aebefb1005a5', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.016091Z', location=None, name='Schlauch flex. Metallschlauch NW6 280mm 1.4', synonyms=None, tags=None, version='01.00.000')
# Flow(id='77659027-2e2f-40de-8676-e1575d3d1402', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.022093Z', location=None, name='Sicherheitsventil 437 DN15 / G1/2" 3,5 bar ü', synonyms=None, tags=None, version='01.00.000')
# Flow(id='0e486cad-8600-4bf2-b950-390e7f6fc63e', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.026093Z', location=None, name='2/2-Wege Kugelhahn 1 1/2" PE311027 1.4408/', synonyms=None, tags=None, version='01.00.000')
# Flow(id='c5f0ae13-60f5-485f-a158-bbcd7b3b4126', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.029960Z', location=None, name='Ozonerzeuger EOZ-HP XL 910 Komple', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1447cf00-d959-48ad-9853-72ac6e7834d5', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.034139Z', location=None, name='Niedrige Sechskantmutter ISO 4035-M10-A2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='18d38974-5da9-4ec1-ac0a-f9f78fdf4334', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.038141Z', location=None, name='Federring 10 DIN127 A2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='e0722944-fdac-4d80-a61f-818e082a5d49', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.041693Z', location=None, name='Stiftschraube DIN 938-M10x55-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4a5570c6-b9b7-4515-a4fb-a36b62d9374d', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.045695Z', location=None, name='Hochspannungs-Durchführung K-180-AR-1/J-C', synonyms=None, tags=None, version='01.00.000')
# Flow(id='9e7a680f-13aa-4fae-bf27-f4d521482ea1', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.050533Z', location=None, name='Sechskantschraube ISO 4017-M8x12-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1cf03b11-1e50-4cfc-ae90-16f10410f8f5', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.055531Z', location=None, name='Sechskantschraube ISO 4017-M6x12-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='f1f26799-85d0-4abc-9be0-113f21344fdd', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.058533Z', location=None, name='Rundstab Ø2,5x3000 EN10278 h9 1.4301', synonyms=None, tags=None, version='01.00.000')
# Flow(id='78707bf4-6882-44cd-b71d-60f91c18a914', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.063689Z', location=None, name='Flachdichtung TEALON TF 1570 blau PTFE 10', synonyms=None, tags=None, version='01.00.000')
# Flow(id='62b285aa-8500-4d1c-8a7f-7b6534c2db88', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.066690Z', location=None, name='Verbindungsblech f. Elektroden 19x0,5  1.4404', synonyms=None, tags=None, version='01.00.000')
# Flow(id='dd503b01-492e-46cd-b6b3-4b380cb857cf', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.070994Z', location=None, name='Klemmstück EOZ M6/M8 -  SW17x20 1.4307', synonyms=None, tags=None, version='01.00.000')
# Flow(id='9c6b2edf-e1d2-468e-af36-da5eef32d8a6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.074996Z', location=None, name='Klemmstück EOZ M6/M7 - SW14x25 1.4307', synonyms=None, tags=None, version='01.00.000')
# Flow(id='182c7e88-18f0-48c0-939f-3ec0c0ecb756', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.080005Z', location=None, name='Hutmutter DIN 1587-M10-A2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='7cd3e067-2d1b-4fa9-a715-c37b467c8626', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.084006Z', location=None, name='Flanschring für HSPD 250 A - 316L', synonyms=None, tags=None, version='01.00.000')
# Flow(id='75689e7f-8090-41cf-9285-c32355762685', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.088888Z', location=None, name='Elektrodenmodul Effizon evo 2G MKII ø8,3', synonyms=None, tags=None, version='01.00.000')
# Flow(id='7cf8af2d-b971-4932-b07a-b5ca21bb975f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.094776Z', location=None, name='Ozonerzeuger  EOZ-HP XL 910- Fertigung', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6aabf621-99cd-41d0-8061-c068e3dd4b2a', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.099732Z', location=None, name='Verteilerwinkel 45x30x4x160 4-Loch 1.4301', synonyms=None, tags=None, version='01.00.000')
# Flow(id='c55eff82-722f-4e66-bb51-6726e3971e9f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.103731Z', location=None, name='Scheibe ISO 7089-10-200HV-A2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='34332c72-0696-4a7d-8719-c82360263570', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.108695Z', location=None, name='Sechskantmutter ISO 4032-M10-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='2cb64fe1-978d-4710-9c85-2ab512f9fca7', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.114692Z', location=None, name='Sechskantmutter ISO 4032-M7-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='fa436858-a50b-416f-af10-e4750caa4bcd', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.119646Z', location=None, name='Sechskantschraube ISO 4017-M6x16-A2-70', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6144413e-415b-4928-8427-f673341ffed4', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.126643Z', location=None, name='Flachdichtungsband 10x3 PTFE', synonyms=None, tags=None, version='01.00.000')
# Flow(id='8e8250f4-34e7-450f-800d-42b9fc1d548b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.132644Z', location=None, name='Engineeringvorgabe fehlt', synonyms=None, tags=None, version='01.00.000')
# Flow(id='92d61da3-6df1-4de9-9710-fb91d549936d', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.137645Z', location=None, name='Baugr. SMO 910 ETM 1G1 1G2 1G3 kal', synonyms=None, tags=None, version='01.00.000')
# Flow(id='adb67be5-f314-487c-a967-b12684747342', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.143650Z', location=None, name='Schaltschrank 1000X2000X600 VX25 Stahlblec', synonyms=None, tags=None, version='01.00.000')
# Flow(id='b4f3fc78-bb87-4b8c-bbb9-f60502b53c49', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.149652Z', location=None, name='Seitenwand 2000X600 RAL7035 VX25', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6253b804-7876-4186-b0ed-09d813bd0f42', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.154653Z', location=None, name='Kabeldurchführung SV 9665.750 250x160mm I', synonyms=None, tags=None, version='01.00.000')
# Flow(id='fd74090d-4833-4aae-9d3d-8311d01b3235', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.160654Z', location=None, name='Winkel Adapter LSC Rahmen 2000 mm 380683', synonyms=None, tags=None, version='01.00.000')
# Flow(id='aa356aea-9f63-4e50-9780-70c37773cd4d', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.165656Z', location=None, name='Profilschiene Simatic S7-1500 160mm', synonyms=None, tags=None, version='01.00.000')
# Flow(id='be9508b1-5aba-468e-80c8-e40e73f21b4f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.169791Z', location=None, name='LSC-A-Rahmen 950 x 1880 mm', synonyms=None, tags=None, version='01.00.000')
# Flow(id='b434e7c0-2308-44ea-abd9-ae30508f10c4', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.175793Z', location=None, name='TS Montagesteg TS4696.000', synonyms=None, tags=None, version='01.00.000')
# Flow(id='0404d945-30de-49c3-b072-2e58180366df', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.180465Z', location=None, name='Montagesteg 14X39mm für 500mm Schrank VX', synonyms=None, tags=None, version='01.00.000')
# Flow(id='6dc6324e-9d53-464e-b53d-9461ee332002', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.183914Z', location=None, name='Tragschiene 600mm PS4396', synonyms=None, tags=None, version='01.00.000')
# Flow(id='3e5587dc-8da8-48e5-b2b1-1d18893ee105', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.188486Z', location=None, name='Kabeldurchführung SV 9665.760 250x160 IP55', synonyms=None, tags=None, version='01.00.000')
# Flow(id='631ca007-5f04-48f3-a632-8f24b3686035', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.193482Z', location=None, name='Gehäusekasten SZ2514 PS für Schaltplan', synonyms=None, tags=None, version='01.00.000')
# Flow(id='0832f20e-2f17-4be1-bc64-94b590d38bff', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.200484Z', location=None, name='Verdrahtungskanal BA6 60x25 Tehalit PVC-har', synonyms=None, tags=None, version='01.00.000')
# Flow(id='5e76af93-fce7-44df-b687-d0b3e380e115', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.206486Z', location=None, name='Profilschiene 2mm OBO St-verz.', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a903c684-12de-40c5-8c38-f1e59986511f', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.211269Z', location=None, name='Metallschutzschlauch SPR-PU-AS 38x4', synonyms=None, tags=None, version='01.00.000')
# Flow(id='eacea75c-644a-4856-9e4f-910c18f58df6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:28.214996Z', location=None, name='Schaltschrank 1200X2000X800 VX25, EMV', synonyms=None, tags=None, version='01.00.000')
# ...
# Flow(id='146e0465-3509-4d5e-8639-ab1cfa31ed4b', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.066589Z', location=None, name='Reduktion, kurz DIN EN ISO 15493 32(da)-25(d', synonyms=None, tags=None, version='01.00.000')
# Flow(id='3e62d4fa-a441-4e8c-9589-5c6c2c42a3b0', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.071591Z', location=None, name='Reduziernippel DIN EN ISO 15493 25(da)-1/2" (', synonyms=None, tags=None, version='01.00.000')
# Flow(id='9a0b82b8-86ea-4c35-85b3-13ab879daa64', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.077592Z', location=None, name='Winkel 90° DIN EN ISO 15493 25(di) PN16 PV', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4ce2b409-0fa2-4553-906f-241582972476', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.082598Z', location=None, name='Verschraubung DIN EN ISO 15493 25(di) PN16', synonyms=None, tags=None, version='01.00.000')
# Flow(id='2e7c3141-65f5-4e1a-8428-60473ed65b24', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.088600Z', location=None, name='Bundbuchse, flach DIN EN ISO 15493 32(di) PN', synonyms=None, tags=None, version='01.00.000')
# Flow(id='df8eae17-59d6-42f8-8f67-61be905bd1b0', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.094600Z', location=None, name='Rohrklemme 25mm PE', synonyms=None, tags=None, version='01.00.000')
# Flow(id='222c926e-16f8-4af7-bff4-b6a5c7fca3cf', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.108604Z', location=None, name='Flachdichtung/Stahleinlage DN25 32x71x3 EPD', synonyms=None, tags=None, version='01.00.000')
# Flow(id='41106736-1cc3-4710-bf9c-dc5113e4b041', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.117606Z', location=None, name='Durchflußmesser DFM185 100-1000l/h DN20 P', synonyms=None, tags=None, version='01.00.000')
# Flow(id='f539f02a-8347-46cb-9b43-7d24a8b3c31c', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.138610Z', location=None, name='Rohr DIN EN ISO 1452-2 25(da) x 1,9 PN16 PV', synonyms=None, tags=None, version='01.00.000')
# Flow(id='f94d824e-1723-4887-b004-47344ecb7f17', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.149613Z', location=None, name='Doppelnippel, egal-EN10241-1/2"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='245aee7b-aa5a-4072-9041-c38bfd2083cf', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.159374Z', location=None, name='Reduzierstück-EN10241-3/4"x3/8"-1.4571/V4A', synonyms=None, tags=None, version='01.00.000')
# Flow(id='4fcf3e12-0dc1-4ae1-8cbd-60a55e5d099a', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.165369Z', location=None, name='T-Stück, egaler Abgang-EN10241-3/8"-1.4571/V', synonyms=None, tags=None, version='01.00.000')
# Flow(id='76ed2b51-1925-4bb8-b355-ee09af9368b3', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.172416Z', location=None, name='Losflansch DIN EN ISO 15494 42(di) PN16 PP/', synonyms=None, tags=None, version='01.00.000')
# Flow(id='d737d925-3a5e-47b7-8be5-7e5d69763101', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.185420Z', location=None, name='Plattenwärmetauscher B5Hx20/1P-SC-M 3/4" S', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1cedeeeb-58df-4233-99d0-0426a6caa8e4', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.194672Z', location=None, name='Gerade Einschraubverschraubungen 6mm - 1/2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='06c21259-681e-4e09-b443-441ce2f43677', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.203773Z', location=None, name='Schlauch PB-8 Swagelok', synonyms=None, tags=None, version='01.00.000')
# Flow(id='3707fd3d-15a6-45a8-9245-0d24f786e590', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.210775Z', location=None, name='2/2-Wege-Kugelhahn 1/2" TB115323 Ms', synonyms=None, tags=None, version='01.00.000')
# Flow(id='25aaa484-7bd3-4011-a5b4-29ca4a85a287', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.218776Z', location=None, name='Flamco Anschlußgruppe 3/4" mit Absperrventil', synonyms=None, tags=None, version='01.00.000')
# Flow(id='ab952022-cf0c-45d0-8550-065bdad809be', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.223777Z', location=None, name='Sicherheitsventil 1/2"_Rotguss 3,5 bar', synonyms=None, tags=None, version='01.00.000')
# Flow(id='e8e12b16-6443-4d6e-af21-07e5a3026998', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.228779Z', location=None, name='Ausdehnungsgefäß 4L, 3/4"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='053dba94-c81b-4617-bc5c-5b81060fa6a8', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.234780Z', location=None, name='Montagerahmen VF160 3420x795x180 S235', synonyms=None, tags=None, version='01.00.000')
# Flow(id='867689f4-2699-4bd3-a3c6-a92c73d89ee9', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.239781Z', location=None, name='Seilspreizer PSU S235JRG2', synonyms=None, tags=None, version='01.00.000')
# Flow(id='bf7dd45a-9b3b-4b89-b674-8624f0664388', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.245782Z', location=None, name='Montagerahmen Alu VF160 - PSU', synonyms=None, tags=None, version='01.00.000')
# Flow(id='53686a37-9a1d-4dd9-a3a9-37fb5b2c1370', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.251784Z', location=None, name='Hochdruck-Kreiselpumpe 3SV11F0024T QQV', synonyms=None, tags=None, version='01.00.000')
# Flow(id='467cda20-e87d-48b2-bd3d-72e0cd33c065', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.256785Z', location=None, name='Temperaturregler Tri-CTR DN20 Rg', synonyms=None, tags=None, version='01.00.000')
# Flow(id='c0dfd20a-6801-4c44-b0fc-7a1bd0826ccc', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.288792Z', location=None, name='Einschraubverschraubung ,gerade 12,7mm-1/4"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='80917b3e-cb5d-4f9c-8257-10faa5bd1253', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.296794Z', location=None, name='Einschraubverschraubung ,gerade 12,7mm-3/8"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1b4f44f4-1c22-4c6f-a6eb-6e134d1c17d6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.313798Z', location=None, name='Einschraubverschraubung ,gerade 12,7mm-1/2"', synonyms=None, tags=None, version='01.00.000')
# Flow(id='e3705910-03bb-440f-b747-67902b2e6582', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.320800Z', location=None, name='Winkeleinschraubverschraubung 19,1mm-3/4"-', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a4e32e8f-2a5c-4fcc-bfdd-808789eea5d8', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.327801Z', location=None, name='Schottverschraubung ,gerade 12,7mm SS', synonyms=None, tags=None, version='01.00.000')
# Flow(id='1b1c6f9d-1f9b-4040-846e-a408151d057c', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.333802Z', location=None, name='Rohr nahtlos 12,7x1,2 SS', synonyms=None, tags=None, version='01.00.000')
# Flow(id='fd09c051-6de5-4fe1-bd67-693c3cf895d6', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.338866Z', location=None, name='Schlauchanschlussstück 12,7mm-12,7mm SS', synonyms=None, tags=None, version='01.00.000')
# Flow(id='c4448d85-3668-493c-a57a-c3b1a7b5ffa3', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.345861Z', location=None, name='Dichtung DR M20 HD Dichtring mit NBR M20 G', synonyms=None, tags=None, version='01.00.000')
# Flow(id='a43710af-f639-4e71-a412-f818fb62ddec', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.351863Z', location=None, name='Halterungsschelle kpl. 12,7mm DIN3015 PA SP', synonyms=None, tags=None, version='01.00.000')
# Flow(id='d50b8b32-a681-4ba2-bc73-14fe83028d20', cas=None, category='Xylem_flow', description=None, flow_properties=[FlowPropertyFactor(conversion_factor=None, flow_property=None, is_ref_flow_property=None)], flow_type=<FlowType.PRODUCT_FLOW: 'PRODUCT_FLOW'>, formula=None, is_infrastructure_flow=None, last_change='2024-05-22T15:01:29.358865Z', location=None, name='Konsole mit Spannband reflex 8-25 Liter', synonyms=None, tags=None, version='01.00.000')
